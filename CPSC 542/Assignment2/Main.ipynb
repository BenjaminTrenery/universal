# %%
import import_ipynb
import Segmentation_Classification_Model as scm
# Out:
# importing Jupyter notebook from Segmentation_Classification_Model.ipynb
# 2024-03-21 02:07:13.477045: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-21 02:07:14.105480: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Skipping, found downloaded files in "./augmented-forest-segmentation" (use force=True to force download)

# %%
datasetCSVFilePath = "augmented-forest-segmentation/meta_data.csv"
datasetFolderPath = "augmented-forest-segmentation/Forest Segmented/Forest Segmented"
# classNames = ["carnation", "iris", "bluebells", "golden english", "roses", "fallen nephews", "tulips",
#               "marigolds", "dandelions", "chrysanthemums", "black-eyed daisies", "water lilies", 
#               "sunflowers", "daisies"]

testModel = scm.SegmentationClassificationModel(datasetCSVFilePath, datasetFolderPath, "image", "mask", 256, 256, 3)

# %%
testModel.getDataset()

# %%
print(testModel.X.shape)
print(testModel.y.shape)
# Out:
# (5108, 256, 256, 3)
# (5108, 256, 256, 1)

# %%
testModel.trainTestSplit()

# %%
testModel.preProcessing()

# %%
testModel.trainValSplit()

# %%
testModel.augmentDataset(True, True, 20, 20)

# %%
testModel.displayClassImages()

# %%
testModel.uNetModel(0.1)
# Out:
# 2024-03-21 02:12:42.257439: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:282] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 testModel.uNetModel(0.1)
#
# File <string>:168, in uNetModel(self, dropoutRate)
#
# AttributeError: 'SegmentationClassificationModel' object has no attribute 'num_classes'

# %%
testModel.compileAndFitUNetModel(0.01, 20)
# Out:
# Epoch 1/20
# /home/codespace/.python/current/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:599: UserWarning: "`sparse_categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a Softmax activation and thus does not represent logits. Was this intended?
#   output, from_logits = _get_logits(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 testModel.compileAndFitUNetModel(0.01, 20)
#
# File <string>:212, in compileAndFitUNetModel(self, learningRate, numEpochs)
#
# File ~/.python/current/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/.python/current/lib/python3.10/site-packages/keras/src/backend/tensorflow/nn.py:616, in sparse_categorical_crossentropy(target, output, from_logits, axis)
#     610     raise ValueError(
#     611         "Argument `output` must be at least rank 1. "
#     612         "Received: "
#     613         f"output.shape={output.shape}"
#     614     )
#     615 if len(target.shape) != len(output.shape[:-1]):
# --> 616     raise ValueError(
#     617         "Argument `output` must have rank (ndim) `target.ndim - 1`. "
#     618         "Received: "
#     619         f"target.shape={target.shape}, output.shape={output.shape}"
#     620     )
#     621 for e1, e2 in zip(target.shape, output.shape[:-1]):
#     622     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Argument `output` must have rank (ndim) `target.ndim - 1`. Received: target.shape=(None, 1), output.shape=(None, 64, 64, 14)

# %%
testModel.showModelLoss()

# %%
testModel.showModelAccuracy()

# %%
testModel.showTable()
