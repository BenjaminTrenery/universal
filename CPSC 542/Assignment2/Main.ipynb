# %%
#imports the class file

import import_ipynb
import Segmentation_Classification_Model as scm
# Out:
# importing Jupyter notebook from Segmentation_Classification_Model.ipynb
# 2024-03-21 13:13:44.778087: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-03-21 13:13:46.050381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Skipping, found downloaded files in "./augmented-forest-segmentation" (use force=True to force download)

# %%
datasetCSVFilePath = "augmented-forest-segmentation/meta_data.csv"
datasetFolderPath = "augmented-forest-segmentation/Forest Segmented/Forest Segmented"

testModel = scm.SegmentationClassificationModel(datasetCSVFilePath, 1, datasetFolderPath, "image", "mask", 256, 256, 3)

# %%
testModel.getDataset()

# %%
print(testModel.X.shape)
print(testModel.y.shape)
# Out:
# (5108, 256, 256, 3)
# (5108, 256, 256, 1)

# %%
testModel.trainTestSplit()

# %%
testModel.preProcessing()

# %%
testModel.trainValSplit()

# %%
testModel.augmentDataset(True, True, 20, 20)

# %%
testModel.uNetModel(0.1)
# Out:
# 2024-03-21 13:18:02.986199: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
testModel.compileAndFitUNetModel(0.01, 5, 60)
# Out:
# Epoch 1/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 657s 6s/step - accuracy: 0.9957 - loss: 0.4457 - val_accuracy: 1.0000 - val_loss: 1.1144e-04
# Epoch 2/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 772s 7s/step - accuracy: 1.0000 - loss: 6.1797e-04 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 3/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 944s 9s/step - accuracy: 1.0000 - loss: 5.9583e-04 - val_accuracy: 1.0000 - val_loss: 2.3975e-14
# Epoch 4/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 841s 8s/step - accuracy: 1.0000 - loss: 4.2981e-04 - val_accuracy: 1.0000 - val_loss: 7.1215e-09
# Epoch 5/5
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 792s 8s/step - accuracy: 1.0000 - loss: 7.0519e-05 - val_accuracy: 1.0000 - val_loss: 1.6704e-07

# %%
testModel.showModelLoss()

# %%
testModel.showModelAccuracy()

# %%
testModel.showTable()
